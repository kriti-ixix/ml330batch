# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('df1')
df2 = pd.read_csv('df2')
df3 = pd.read_csv('df3')

# %%
df1
# Out:
#      Unnamed: 0         A         B         C         D
# 0    2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1    2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2    2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3    2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4    2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ..          ...       ...       ...       ...       ...
# 995  2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 996  2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 997  2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 998  2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 999  2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 5 columns]

# %%
df2
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df3
# Out:
#             a         b         c         d
# 0    0.336272  0.325011  0.001020  0.401402
# 1    0.980265  0.831835  0.772288  0.076485
# 2    0.480387  0.686839  0.000575  0.746758
# 3    0.502106  0.305142  0.768608  0.654685
# 4    0.856602  0.171448  0.157971  0.321231
# ..        ...       ...       ...       ...
# 495  0.528705  0.226122  0.055835  0.131962
# 496  0.324730  0.215201  0.935302  0.794115
# 497  0.118036  0.264574  0.629206  0.824062
# 498  0.227021  0.660209  0.851353  0.478676
# 499  0.466157  0.753000  0.115391  0.279712
#
# [500 rows x 4 columns]

# %%
# %matplotlib inline

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df1['A'].hist(bins=30, grid=False)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.area()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(stacked=False)
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True, rot=180)
# Out:
# <AxesSubplot:>

# %%
df1.plot.line(figsize=(12, 8), lw=0.5)
# Out:
# <AxesSubplot:>

# %%
df2.plot.line()
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='viridis', figsize=(12, 10))
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.hexbin(x='A', y='B', cmap='viridis', figsize=(12, 10), gridsize=26)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.hexbin(x='A', y='B', cmap='Oranges', figsize=(12, 10), gridsize=26)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.hexbin(x='A', y='B', cmap='spring', figsize=(12, 10), gridsize=26)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.hexbin(x='A', y='B', cmap='hsv', figsize=(12, 10), gridsize=26)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>
